# %%
import numpy as np
import re
from collections import defaultdict
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import gensim
import gensim.corpora as corpora
from gensim.models import CoherenceModel
import matplotlib.pyplot as plt

# %%
train_df = pd.read_csv("train.csv")
test_df = pd.read_csv("test.csv")

# %%
train_df.head()
# Out:
#    spam  \
# 0     0
# 1     1
# 2     1
# 3     1
# 4     0
#
#                                                                                                   text
# 0  subject institute international finance annual subscription shirley yes vince shirley crenshaw p...
# 1  subject mortgage even worst credit zwzm detail want refinance fill quick form immediately mortga...
# 2  subject partnership mr edward moko independence close johannesburg south africa dear sir madam w...
# 3  subject de la part de enfants ama rue de martyr avenue delafosse b p abidjan republique de cote ...
# 4  subject synfuel option valuation lenny believe must done home work tax credit issue however may ...

# %%
ham_train_df = train_df[train_df['spam'] == 0]
spam_train_df = train_df[train_df['spam'] == 1]
ham_test_df = test_df[test_df['spam'] == 0]
spam_test_df = test_df[test_df['spam'] == 1]

# %%
ham_train_df.head()
# Out:
#    spam  \
# 0     0
# 4     0
# 5     0
# 6     0
# 7     0
#
#                                                                                                   text
# 0  subject institute international finance annual subscription shirley yes vince shirley crenshaw p...
# 4  subject synfuel option valuation lenny believe must done home work tax credit issue however may ...
# 5  subject network planning stinson discussion jim said company name mill three provide modeling to...
# 6  subject spreadsheet george posey george first cut problem gave u done associate clayton vernon p...
# 7  subject fyi new esai report forecasting power price eastern market attached new report forecasti...

# %%
spam_train_df.head()
# Out:
#     spam  \
# 1      1
# 2      1
# 3      1
# 10     1
# 12     1
#
#                                                                                                    text
# 1   subject mortgage even worst credit zwzm detail want refinance fill quick form immediately mortga...
# 2   subject partnership mr edward moko independence close johannesburg south africa dear sir madam w...
# 3   subject de la part de enfants ama rue de martyr avenue delafosse b p abidjan republique de cote ...
# 10  subject considered unsolicited bulk email message distmatu agrocom com ar considered unsolicited...
# 12  subject get thru july newsletter get thru newslettervenita king get thru coach volume issue july...

# %%
ham_test_df.head()
# Out:
#     spam  \
# 1      0
# 4      0
# 7      0
# 11     0
# 12     0
#
#                                                                                                    text
# 1   subject storage model security stinson added time bomb security file check model ready release b...
# 4   subject video conference ross mcintyre vince received invitation lotus note outline vc location ...
# 7   subject erisk iconference please save e mail contains important information event thank register...
# 11  subject trading algorithm andy sound good one comment vasant swamped work coordinating several h...
# 12  subject yes sir jeff thanks shall try arrange video conference houston howard back vince pm plea...

# %%
spam_test_df.head()
# Out:
#    spam  \
# 0     1
# 2     1
# 3     1
# 5     1
# 6     1
#
#                                                                                                   text
# 0  subject perfect logo charset koi r thinking breathing new life business start revamping front en...
# 2  subject wall street micro news report homeland security investment terror attack united state se...
# 3  subject logo stationer website design much lt really hard recollect company market full sugqesti...
# 5  subject perfect logo charset koi r thinking breathing new life business start revamping front en...
# 6  subject save money buy getting thing tried cialls yet even imagine like real man bed thing great...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   spam    5000 non-null   int64
#  1   text    5000 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 78.2+ KB

# %%
test_df.head()
# Out:
#    spam  \
# 0     1
# 1     0
# 2     1
# 3     1
# 4     0
#
#                                                                                                   text
# 0  subject perfect logo charset koi r thinking breathing new life business start revamping front en...
# 1  subject storage model security stinson added time bomb security file check model ready release b...
# 2  subject wall street micro news report homeland security investment terror attack united state se...
# 3  subject logo stationer website design much lt really hard recollect company market full sugqesti...
# 4  subject video conference ross mcintyre vince received invitation lotus note outline vc location ...

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226 entries, 0 to 225
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   spam    226 non-null    int64
#  1   text    226 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 3.7+ KB

# %%
nltk.download(['stopwords', 'wordnet'])
sw = stopwords.words('english')
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# !unzip /usr/share/nltk_data/corpora/wordnet.zip -d /usr/share/nltk_data/corpora/
# Out:
# unzip:  cannot find or open /usr/share/nltk_data/corpora/wordnet.zip, /usr/share/nltk_data/corpora/wordnet.zip.zip or /usr/share/nltk_data/corpora/wordnet.zip.ZIP.

# %%
def clean_text(text):
    text = text.lower()
    punctuations = '\\@#!?+&*[]-%.:/();$=><|{}^' + "'`" + '_'
    for p in punctuations:
        text = text.replace(p,' ')
    text = re.sub(r'[ ]+'," ",text)
    text = re.sub(r'\d+'," ",text)
    text = [word for word in text.split() if len(word) > 1]
    text = [word for word in text if word not in sw]
    text = [lemmatizer.lemmatize(word) for word in text]
    return text

# %%
train_df['text'] = train_df['text'].apply(lambda x: clean_text(x))
test_df['text'] = test_df['text'].apply(lambda x: clean_text(x))
ham_train_df['text'] = ham_train_df['text'].apply(lambda x: clean_text(x))
spam_train_df['text'] = spam_train_df['text'].apply(lambda x: clean_text(x))
ham_test_df['text'] = ham_test_df['text'].apply(lambda x: clean_text(x))
spam_test_df['text'] = spam_test_df['text'].apply(lambda x: clean_text(x))
# Out:
# <ipython-input-130-8c1b9e28324c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ham_train_df['text'] = ham_train_df['text'].apply(lambda x: clean_text(x))
# <ipython-input-130-8c1b9e28324c>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spam_train_df['text'] = spam_train_df['text'].apply(lambda x: clean_text(x))
# <ipython-input-130-8c1b9e28324c>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ham_test_df['text'] = ham_test_df['text'].apply(lambda x: clean_text(x))
# <ipython-input-130-8c1b9e28324c>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spam_test_df['text'] = spam_test_df['text'].apply(lambda x: clean_text(x))

# %%
train_id2word = corpora.Dictionary(train_df['text'].tolist())
test_id2word = corpora.Dictionary(test_df['text'].tolist())

ham_train_id2word = corpora.Dictionary(ham_train_df['text'].tolist())
spam_train_id2word = corpora.Dictionary(spam_train_df['text'].tolist())
ham_test_id2word = corpora.Dictionary(ham_test_df['text'].tolist())
spam_test_id2word = corpora.Dictionary(spam_test_df['text'].tolist())


train_corpus = [train_id2word.doc2bow(text) for text in train_df['text'].tolist()]
test_corpus = [test_id2word.doc2bow(text) for text in test_df['text'].tolist()]

ham_train_corpus = [ham_train_id2word.doc2bow(text) for text in ham_train_df['text'].tolist()]
spam_train_corpus = [spam_train_id2word.doc2bow(text) for text in spam_train_df['text'].tolist()]
ham_test_corpus = [ham_test_id2word.doc2bow(text) for text in ham_test_df['text'].tolist()]
spam_test_corpus = [spam_test_id2word.doc2bow(text) for text in spam_test_df['text'].tolist()]

# %%
def perform_LDA(data, id2word, corpus):
  perplexities = []
  coherences = []
  lda_model = gensim.models.LdaMulticore(corpus=corpus, id2word=id2word, num_topics=5, random_state=42,
                                          chunksize=100, passes=15, alpha=50/5, per_word_topics=True, workers=4)
  perplexities.append(lda_model.log_perplexity(corpus))
  coherence_model_lda = CoherenceModel(model=lda_model, texts=data['text'].tolist(),
                                  dictionary=id2word, coherence='c_v')
  coherences.append(coherence_model_lda.get_coherence())
  return perplexities, coherences

# %%
train_perplexities, train_coherences = perform_LDA(train_df, train_id2word, train_corpus)
test_perplexities, test_coherences = perform_LDA(test_df, test_id2word, test_corpus)
ham_train_perplexities, ham_train_coherences = perform_LDA(ham_train_df, ham_train_id2word, ham_train_corpus)
spam_train_perplexities, spam_train_coherences = perform_LDA(spam_train_df, spam_train_id2word, spam_train_corpus)
ham_test_perplexities, ham_test_coherences = perform_LDA(ham_test_df, ham_test_id2word, ham_test_corpus)
spam_test_perplexities, spam_test_coherences = perform_LDA(spam_test_df, spam_test_id2word, spam_test_corpus)

# %%
# Perplexity scores closer to 0 indicate the models effectiveness and confidence in predicting the correct topics
# pertaining to a specific dataset.
print("train perplexity:", train_perplexities, "test perplexity:", test_perplexities)
print("train_coherence:", train_coherences, "test coherence:", test_coherences)
print("ham_train_perplexity:", ham_train_perplexities, "ham_train_coherence:", ham_train_coherences)
print("spam_train_perplexity:", spam_train_perplexities, "spam_train_coherence:", spam_train_coherences)
print("ham_test_perplexity:", ham_test_perplexities, "ham_test_coherence:", ham_test_coherences)
print("spam_test_perplexity:", spam_test_perplexities, "spam_test_coherence:", spam_test_coherences)
# Out:
# train perplexity: [-7.9274476128621645] test perplexity: [-8.205876082990107]
# train_coherence: [0.5384917410114357] test coherence: [0.40012360703584476]
# ham_train_perplexity: [-7.667251421543368] ham_train_coherence: [0.5101150278696103]
# spam_train_perplexity: [-7.8539583230060686] spam_train_coherence: [0.41704589646345297]
# ham_test_perplexity: [-7.720414514892661] ham_test_coherence: [0.4114241328233096]
# spam_test_perplexity: [-8.105793473338052] spam_test_coherence: [0.3692178469238556]

# %%
train_lda_model = gensim.models.ldamodel.LdaModel(corpus=train_corpus, id2word=train_id2word, num_topics=5, random_state=42, update_every=1,
                                           chunksize=100, passes=15, alpha='auto', per_word_topics=True)
test_lda_model = gensim.models.ldamodel.LdaModel(corpus=test_corpus, id2word=test_id2word, num_topics=5, random_state=42, update_every=1,
                                           chunksize=100, passes=15, alpha='auto', per_word_topics=True)
ham_train_lda_model = gensim.models.ldamodel.LdaModel(corpus=ham_train_corpus, id2word=ham_train_id2word, num_topics=5, random_state=42, update_every=1,
                                           chunksize=100, passes=15, alpha='auto', per_word_topics=True)
ham_test_lda_model = gensim.models.ldamodel.LdaModel(corpus=ham_test_corpus, id2word=ham_test_id2word, num_topics=5, random_state=42, update_every=1,
                                           chunksize=100, passes=15, alpha='auto', per_word_topics=True)
spam_train_lda_model = gensim.models.ldamodel.LdaModel(corpus=spam_train_corpus, id2word=spam_train_id2word, num_topics=5, random_state=42, update_every=1,
                                           chunksize=100, passes=15, alpha='auto', per_word_topics=True)
spam_test_lda_model = gensim.models.ldamodel.LdaModel(corpus=spam_test_corpus, id2word=spam_test_id2word, num_topics=5, random_state=42, update_every=1,
                                           chunksize=100, passes=15, alpha='auto', per_word_topics=True)

# %%
def lda_to_df(model, corpus):
    topic_probs = model.get_document_topics(corpus)
    topic_dict = [dict(x) for x in topic_probs]
    df = pd.DataFrame(topic_dict).fillna(0)
    df['docs'] = df.index.values
    df.columns = df.columns.astype(str)
    return df

def get_best_docs(df, n, k, texts):
    k_cols = range(0, k)
    n_rep_docs_dict = defaultdict(list)
    for i in k_cols:
        if str(i) in df.columns:
            inds = df.nlargest(n = n, columns = str(i))['docs'].astype(int).tolist()
            n_rep_docs_dict[i] += [texts[ind] for ind in inds]
    return n_rep_docs_dict

# %%
train_df_topics_docs = lda_to_df(train_lda_model, train_corpus)
print("train: ",train_df_topics_docs)
test_df_topics_docs = lda_to_df(test_lda_model, test_corpus)
print("test: ",test_df_topics_docs)
ham_train_df_topics_docs = lda_to_df(ham_train_lda_model, ham_train_corpus)
print("ham train: ", ham_train_df_topics_docs)
ham_test_df_topics_docs = lda_to_df(ham_test_lda_model, ham_test_corpus)
print("ham test: ",ham_test_df_topics_docs)
spam_train_df_topics_docs = lda_to_df(spam_train_lda_model, spam_train_corpus)
print("spam train: ", spam_train_df_topics_docs)
spam_test_df_topics_docs = lda_to_df(spam_test_lda_model, spam_test_corpus)
print("spam test: ",spam_test_df_topics_docs)
# Out:
# train:               0         1         4         2         3  docs
# 0     0.830515  0.139944  0.027840  0.000000  0.000000     0
# 1     0.000000  0.959570  0.000000  0.028080  0.000000     1
# 2     0.044486  0.700765  0.254334  0.000000  0.000000     2
# 3     0.064950  0.103539  0.056310  0.774729  0.000000     3
# 4     0.643560  0.110318  0.166078  0.000000  0.079768     4
# ...        ...       ...       ...       ...       ...   ...
# 4995  0.000000  0.988307  0.000000  0.000000  0.000000  4995
# 4996  0.000000  0.000000  0.000000  0.000000  0.994015  4996
# 4997  0.422081  0.000000  0.131398  0.440815  0.000000  4997
# 4998  0.000000  0.927514  0.000000  0.000000  0.063496  4998
# 4999  0.213011  0.379118  0.366209  0.021888  0.019774  4999
#
# [5000 rows x 6 columns]
# test:              3         0         1         2         4  docs
# 0    0.995375  0.000000  0.000000  0.000000  0.000000     0
# 1    0.765978  0.227144  0.000000  0.000000  0.000000     1
# 2    0.788768  0.000000  0.210987  0.000000  0.000000     2
# 3    0.997843  0.000000  0.000000  0.000000  0.000000     3
# 4    0.000000  0.856874  0.114492  0.027247  0.000000     4
# ..        ...       ...       ...       ...       ...   ...
# 221  0.000000  0.998343  0.000000  0.000000  0.000000   221
# 222  0.000000  0.000000  0.000000  0.000000  0.995842   222
# 223  0.000000  0.000000  0.000000  0.000000  0.994435   223
# 224  0.000000  0.000000  0.998860  0.000000  0.000000   224
# 225  0.000000  0.000000  0.000000  0.997941  0.000000   225
#
# [226 rows x 6 columns]
# ham train:               0         1         2         3         4  docs
# 0     0.029289  0.569052  0.221631  0.168748  0.011280     0
# 1     0.000000  0.172432  0.000000  0.290596  0.528269     1
# 2     0.264933  0.393505  0.000000  0.242773  0.098081     2
# 3     0.000000  0.425426  0.031956  0.207218  0.333991     3
# 4     0.319174  0.018801  0.325191  0.154172  0.182663     4
# ...        ...       ...       ...       ...       ...   ...
# 2995  0.000000  0.125092  0.000000  0.866619  0.000000  2995
# 2996  0.064944  0.391225  0.000000  0.488776  0.053916  2996
# 2997  0.000000  0.041635  0.518862  0.370503  0.065403  2997
# 2998  0.000000  0.000000  0.567009  0.416287  0.000000  2998
# 2999  0.534081  0.000000  0.035581  0.251691  0.176324  2999
#
# [3000 rows x 6 columns]
# ham test:              4         1         2         0         3  docs
# 0    0.988855  0.000000  0.000000  0.000000  0.000000     0
# 1    0.808018  0.190167  0.000000  0.000000  0.000000     1
# 2    0.000000  0.082145  0.917005  0.000000  0.000000     2
# 3    0.000000  0.094064  0.761828  0.143512  0.000000     3
# 4    0.000000  0.361693  0.636122  0.000000  0.000000     4
# ..        ...       ...       ...       ...       ...   ...
# 108  0.000000  0.000000  0.000000  0.999246  0.000000   108
# 109  0.000000  0.000000  0.000000  0.000000  0.998898   109
# 110  0.000000  0.995936  0.000000  0.000000  0.000000   110
# 111  0.000000  0.998651  0.000000  0.000000  0.000000   111
# 112  0.000000  0.000000  0.000000  0.000000  0.998923   112
#
# [113 rows x 6 columns]
# spam train:               0         3         1         4         2  docs
# 0     0.247745  0.747500  0.000000  0.000000  0.000000     0
# 1     0.074581  0.811710  0.012917  0.097657  0.000000     1
# 2     0.034604  0.095940  0.045388  0.105783  0.718285     2
# 3     0.000000  0.218940  0.770331  0.000000  0.000000     3
# 4     0.851348  0.133369  0.000000  0.014915  0.000000     4
# ...        ...       ...       ...       ...       ...   ...
# 1995  0.213721  0.743838  0.041232  0.000000  0.000000  1995
# 1996  0.000000  0.202821  0.194541  0.000000  0.593970  1996
# 1997  0.104890  0.884289  0.010228  0.000000  0.000000  1997
# 1998  0.000000  0.000000  0.000000  0.000000  0.991541  1998
# 1999  0.997007  0.000000  0.000000  0.000000  0.000000  1999
#
# [2000 rows x 6 columns]
# spam test:              1         2         0        4         3  docs
# 0    0.996401  0.000000  0.000000  0.00000  0.000000     0
# 1    0.016914  0.982883  0.000000  0.00000  0.000000     1
# 2    0.843266  0.155315  0.000000  0.00000  0.000000     2
# 3    0.996401  0.000000  0.000000  0.00000  0.000000     3
# 4    0.000000  0.000000  0.995292  0.00000  0.000000     4
# ..        ...       ...       ...      ...       ...   ...
# 108  0.000000  0.000000  0.000000  0.00000  0.997572   108
# 109  0.000000  0.000000  0.994585  0.00000  0.000000   109
# 110  0.996971  0.000000  0.000000  0.00000  0.000000   110
# 111  0.000000  0.000000  0.000000  0.00000  0.996749   111
# 112  0.000000  0.000000  0.000000  0.99848  0.000000   112
#
# [113 rows x 6 columns]

# %%
train_docs_dict = get_best_docs(train_df_topics_docs, 5, 100, train_df['text'].tolist())
test_docs_dict = get_best_docs(test_df_topics_docs, 5, 100, test_df['text'].tolist())
ham_train_docs_dict = get_best_docs(ham_train_df_topics_docs, 5, 100, ham_train_df['text'].tolist())
ham_test_docs_dict = get_best_docs(ham_test_df_topics_docs, 5, 100, ham_test_df['text'].tolist())
spam_train_docs_dict = get_best_docs(spam_train_df_topics_docs, 5, 100, spam_train_df['text'].tolist())
spam_test_docs_dict = get_best_docs(spam_test_df_topics_docs, 5, 100, spam_test_df['text'].tolist())

# %%
train_lda_model.print_topics()
test_lda_model.print_topics()
ham_train_lda_model.print_topics()
ham_test_lda_model.print_topics()
spam_train_lda_model.print_topics()
spam_test_lda_model.print_topics()
# Out:
# [(0,
#   '0.010*"bank" + 0.008*"subject" + 0.008*"transaction" + 0.007*"document" + 0.007*"mr" + 0.007*"account" + 0.006*"company" + 0.006*"address" + 0.006*"fund" + 0.006*"please"'),
#  (1,
#   '0.021*"review" + 0.016*"price" + 0.016*"adobe" + 0.014*"coupon" + 0.011*"customer" + 0.011*"title" + 0.010*"available" + 0.009*"sale" + 0.008*"system" + 0.008*"download"'),
#  (2,
#   '0.016*"company" + 0.012*"statement" + 0.011*"information" + 0.010*"stock" + 0.009*"com" + 0.009*"within" + 0.007*"make" + 0.007*"email" + 0.007*"security" + 0.006*"newsletter"'),
#  (3,
#   '0.019*"website" + 0.017*"subject" + 0.011*"online" + 0.009*"save" + 0.008*"best" + 0.008*"search" + 0.008*"way" + 0.007*"submit" + 0.006*"com" + 0.006*"time"'),
#  (4,
#   '0.013*"mail" + 0.009*"marketing" + 0.009*"please" + 0.008*"click" + 0.008*"one" + 0.007*"list" + 0.007*"removed" + 0.006*"subject" + 0.006*"next" + 0.006*"technology"')]

# %%
def format_topics_sentences(ldamodel, corpus, texts):
    sent_topics_df = pd.DataFrame()
    for i, row_list in enumerate(ldamodel[corpus]):
        row = row_list[0] if ldamodel.per_word_topics else row_list
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = pd.concat([sent_topics_df, pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]).to_frame().T], ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)

train_df_topic_sents_keywords = format_topics_sentences(train_lda_model, train_corpus, train_df['text'].tolist())
test_df_topic_sents_keywords = format_topics_sentences(test_lda_model, test_corpus, test_df['text'].tolist())
ham_train_df_topic_sents_keywords = format_topics_sentences(ham_train_lda_model, ham_train_corpus, ham_train_df['text'].tolist())
ham_test_df_topic_sents_keywords = format_topics_sentences(ham_test_lda_model, ham_test_corpus, ham_test_df['text'].tolist())
spam_train_df_topic_sents_keywords = format_topics_sentences(spam_train_lda_model, spam_train_corpus, spam_train_df['text'].tolist())
spam_test_df_topic_sents_keywords = format_topics_sentences(spam_test_lda_model, spam_test_corpus, spam_test_df['text'].tolist())

# %%
train_df_dominant_topic = train_df_topic_sents_keywords.reset_index()
train_df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
train_df_dominant_topic.head(25)
# Out:
#     Document_No Dominant_Topic Topic_Perc_Contrib  \
# 0             0              0             0.8305
# 1             1              1             0.9596
# 2             2              1             0.7008
# 3             3              2             0.7747
# 4             4              0             0.6436
# 5             5              0              0.861
# 6             6              0              0.753
# 7             7              0             0.4254
# 8             8              4             0.8454
# 9             9              0             0.8368
# 10           10              2             0.4643
# 11           11              0             0.9412
# 12           12              1             0.8096
# 13           13              0             0.9209
# 14           14              3             0.3859
# 15           15              1             0.9909
# 16           16              0             0.8212
# 17           17              0             0.6705
# 18           18              0             0.9078
# 19           19              0             0.9889
# 20           20              0             0.6894
# 21           21              0             0.9483
# 22           22              0             0.9881
# 23           23              1             0.9862
# 24           24              1             0.9911
#
#                                                                              Keywords  \
# 0                    enron, ect, vince, subject, hou, kaminski, please, would, cc, pm
# 1                   subject, email, free, please, com, http, click, get, new, account
# 2                   subject, email, free, please, com, http, click, get, new, account
# 3                         com, edu, http, rice, message, subject, mail, id, www, html
# 4                    enron, ect, vince, subject, hou, kaminski, please, would, cc, pm
# 5                    enron, ect, vince, subject, hou, kaminski, please, would, cc, pm
# 6                    enron, ect, vince, subject, hou, kaminski, please, would, cc, pm
# 7                    enron, ect, vince, subject, hou, kaminski, please, would, cc, pm
# 8   company, market, power, investment, business, gas, year, information, may, report
# 9                    enron, ect, vince, subject, hou, kaminski, please, would, cc, pm
# 10                        com, edu, http, rice, message, subject, mail, id, www, html
# 11                   enron, ect, vince, subject, hou, kaminski, please, would, cc, pm
# 12                  subject, email, free, please, com, http, click, get, new, account
# 13                   enron, ect, vince, subject, hou, kaminski, please, would, cc, pm
# 14         price, model, software, adobe, curve, subject, energy, option, var, system
# 15                  subject, email, free, please, com, http, click, get, new, account
# 16                   enron, ect, vince, subject, hou, kaminski, please, would, cc, pm
# 17                   enron, ect, vince, subject, hou, kaminski, please, would, cc, pm
# 18                   enron, ect, vince, subject, hou, kaminski, please, would, cc, pm
# 19                   enron, ect, vince, subject, hou, kaminski, please, would, cc, pm
# 20                   enron, ect, vince, subject, hou, kaminski, please, would, cc, pm
# 21                   enron, ect, vince, subject, hou, kaminski, please, would, cc, pm
# 22                   enron, ect, vince, subject, hou, kaminski, please, would, cc, pm
# 23                  subject, email, free, please, com, http, click, get, new, account
# 24                  subject, email, free, please, com, http, click, get, new, account
#
#                                                                                                    Text
# 0   [subject, institute, international, finance, annual, subscription, shirley, yes, vince, shirley,...
# 1   [subject, mortgage, even, worst, credit, zwzm, detail, want, refinance, fill, quick, form, immed...
# 2   [subject, partnership, mr, edward, moko, independence, close, johannesburg, south, africa, dear,...
# 3   [subject, de, la, part, de, enfants, ama, rue, de, martyr, avenue, delafosse, abidjan, republiqu...
# 4   [subject, synfuel, option, valuation, lenny, believe, must, done, home, work, tax, credit, issue...
# 5   [subject, network, planning, stinson, discussion, jim, said, company, name, mill, three, provide...
# 6   [subject, spreadsheet, george, posey, george, first, cut, problem, gave, done, associate, clayto...
# 7   [subject, fyi, new, esai, report, forecasting, power, price, eastern, market, attached, new, rep...
# 8   [subject, enron, india, newsdesk, may, newsclips, stinson, vince, news, article, read, first, on...
# 9   [subject, resume, molly, would, like, bring, student, summer, intern, last, one, running, space,...
# 10  [subject, considered, unsolicited, bulk, email, message, distmatu, agrocom, com, ar, considered,...
# 11  [subject, nelson, nele, interview, vice, interviewed, nelson, last, week, feedback, communicativ...
# 12  [subject, get, thru, july, newsletter, get, thru, newslettervenita, king, get, thru, coach, volu...
# 13  [subject, rice, seminar, hello, fyi, jones, graduate, school, research, seminar, series, finance...
# 14  [subject, efa, meeting, hey, vince, thanks, reply, see, becomes, session, keep, informed, paper,...
# 15  [subject, online, sale, low, enough, visitor, submitting, website, search, engine, may, increase...
# 16  [subject, congratulation, vince, congratulation, mind, always, md, officializing, thank, help, s...
# 17  [subject, kwi, user, group, david, regret, inform, unable, attend, conference, due, previous, co...
# 18  [subject, maureen, raymoin, review, norma, maureen, raymond, refuse, sign, review, please, join,...
# 19  [subject, tage, paul, let, know, made, reservation, thursday, night, june, latour, argent, resta...
# 20  [subject, extreme, value, theory, applied, weathet, dear, vince, grant, currently, reviewing, er...
# 21  [subject, tiger, evals, attachment, tiger, host, understand, host, problem, accessing, database,...
# 22  [subject, year, end, performance, feedback, note, receive, message, time, selected, reviewer, se...
# 23  [subject, rreally, work, good, hello, welcome, pharmonli, thyroid, ne, newtonian, hop, one, lead...
# 24  [subject, know, get, search, engine, result, submitting, website, search, engine, may, increase,...

# %%
test_df_dominant_topic = test_df_topic_sents_keywords.reset_index()
test_df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
test_df_dominant_topic.head(25)
# Out:
#     Document_No Dominant_Topic Topic_Perc_Contrib  \
# 0             0              3             0.9954
# 1             1              3              0.766
# 2             2              3             0.7888
# 3             3              3             0.9978
# 4             4              0             0.8569
# 5             5              3             0.9954
# 6             6              0             0.5039
# 7             7              2             0.7351
# 8             8              3             0.9949
# 9             9              4             0.9921
# 10           10              3             0.7662
# 11           11              3             0.5137
# 12           12              0             0.9967
# 13           13              1             0.7884
# 14           14              3             0.8769
# 15           15              1             0.5053
# 16           16              2             0.9961
# 17           17              2             0.5079
# 18           18              0             0.4761
# 19           19              2             0.9972
# 20           20              1             0.5428
# 21           21              2             0.5606
# 22           22              1             0.7074
# 23           23              3             0.8974
# 24           24              1             0.6088
#
#                                                                             Keywords  \
# 0         model, make, valuation, company, money, price, year, even, business, stock
# 1         model, make, valuation, company, money, price, year, even, business, stock
# 2         model, make, valuation, company, money, price, year, even, business, stock
# 3         model, make, valuation, company, money, price, year, even, business, stock
# 4                     vince, enron, ect, subject, kaminski, pm, cc, hou, com, please
# 5         model, make, valuation, company, money, price, year, even, business, stock
# 6                     vince, enron, ect, subject, kaminski, pm, cc, hou, com, please
# 7         list, review, mail, subject, adobe, email, available, price, click, please
# 8         model, make, valuation, company, money, price, year, even, business, stock
# 9          subject, website, online, way, save, de, submit, customer, search, viagra
# 10        model, make, valuation, company, money, price, year, even, business, stock
# 11        model, make, valuation, company, money, price, year, even, business, stock
# 12                    vince, enron, ect, subject, kaminski, pm, cc, hou, com, please
# 13  power, information, spike, company, business, bank, price, please, account, risk
# 14        model, make, valuation, company, money, price, year, even, business, stock
# 15  power, information, spike, company, business, bank, price, please, account, risk
# 16        list, review, mail, subject, adobe, email, available, price, click, please
# 17        list, review, mail, subject, adobe, email, available, price, click, please
# 18                    vince, enron, ect, subject, kaminski, pm, cc, hou, com, please
# 19        list, review, mail, subject, adobe, email, available, price, click, please
# 20  power, information, spike, company, business, bank, price, please, account, risk
# 21        list, review, mail, subject, adobe, email, available, price, click, please
# 22  power, information, spike, company, business, bank, price, please, account, risk
# 23        model, make, valuation, company, money, price, year, even, business, stock
# 24  power, information, spike, company, business, bank, price, please, account, risk
#
#                                                                                                    Text
# 0   [subject, perfect, logo, charset, koi, thinking, breathing, new, life, business, start, revampin...
# 1   [subject, storage, model, security, stinson, added, time, bomb, security, file, check, model, re...
# 2   [subject, wall, street, micro, news, report, homeland, security, investment, terror, attack, uni...
# 3   [subject, logo, stationer, website, design, much, lt, really, hard, recollect, company, market, ...
# 4   [subject, video, conference, ross, mcintyre, vince, received, invitation, lotus, note, outline, ...
# 5   [subject, perfect, logo, charset, koi, thinking, breathing, new, life, business, start, revampin...
# 6   [subject, save, money, buy, getting, thing, tried, cialls, yet, even, imagine, like, real, man, ...
# 7   [subject, erisk, iconference, please, save, mail, contains, important, information, event, thank...
# 8   [subject, need, outstanding, logo, working, company, image, start, visual, identity, key, first,...
# 9   [subject, ready, get, hello, viagra, med, struggle, men, erectile, dysfunction, like, one, joke,...
# 10  [subject, site, sale, take, credit, card, make, money, easy, set, credit, check, approval, make,...
# 11  [subject, trading, algorithm, andy, sound, good, one, comment, vasant, swamped, work, coordinati...
# 12  [subject, yes, sir, jeff, thanks, shall, try, arrange, video, conference, houston, howard, back,...
# 13  [subject, ferc, soft, price, cap, mean, cera, conference, call, notification, please, accept, ap...
# 14  [subject, uregent, important, information, website, hello, name, steve, scott, president, ceo, w...
# 15  [subject, secure, account, dear, lasalle, bank, customer, recently, noticed, one, attempt, login...
# 16  [subject, loose, fat, day, overweight, loose, pound, every, day, want, loose, weight, fast, natu...
# 17  [subject, java, class, starting, feb, th, note, upcoming, java, class, extremely, high, interest...
# 18  [subject, eol, wti, historical, trade, simulation, stinson, thanks, lot, much, work, done, simul...
# 19  [subject, graphic, software, available, cheap, oem, version, good, morning, offer, latest, oem, ...
# 20  [subject, upside, treasury, linked, annuity, upside, annual, increase, year, note, bonus, credit...
# 21  [subject, save, money, getting, oem, software, need, software, pc, visit, site, might, need, bes...
# 22  [subject, aggressive, investor, watching, sport, alumnus, inc, investor, alert, group, investor,...
# 23  [subject, important, start, adult, entertainment, business, entertainment, draw, lot, traffic, s...
# 24  [subject, fwd, new, commodity, marketplace, opportunity, mark, lay, thank, listening, concept, s...

# %%
ham_train_df_dominant_topic = ham_train_df_topic_sents_keywords.reset_index()
ham_train_df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
ham_train_df_dominant_topic.head(25)
# Out:
#     Document_No Dominant_Topic Topic_Perc_Contrib  \
# 0             0              1             0.5691
# 1             1              4             0.5283
# 2             2              1             0.3935
# 3             3              1             0.4254
# 4             4              2             0.3252
# 5             5              4             0.8384
# 6             6              3             0.6407
# 7             7              3             0.7046
# 8             8              3             0.5654
# 9             9              4             0.7663
# 10           10              3             0.8061
# 11           11              3             0.6896
# 12           12              1             0.6266
# 13           13              1             0.6762
# 14           14              4             0.4984
# 15           15              3             0.4208
# 16           16              0             0.5615
# 17           17              0             0.4751
# 18           18              0             0.4321
# 19           19              3             0.3931
# 20           20              3              0.471
# 21           21              3             0.7333
# 22           22              3             0.4559
# 23           23              4             0.5013
# 24           24              3             0.8885
#
#                                                                              Keywords  \
# 0                  ect, enron, hou, subject, vince, cc, pm, kaminski, shirley, please
# 1               model, power, price, market, energy, option, curve, would, state, var
# 2                  ect, enron, hou, subject, vince, cc, pm, kaminski, shirley, please
# 3                  ect, enron, hou, subject, vince, cc, pm, kaminski, shirley, please
# 4                  com, edu, rice, http, please, request, www, subject, access, anjam
# 5               model, power, price, market, energy, option, curve, would, state, var
# 6           vince, enron, subject, would, com, kaminski, please, research, know, like
# 7           vince, enron, subject, would, com, kaminski, please, research, know, like
# 8           vince, enron, subject, would, com, kaminski, please, research, know, like
# 9               model, power, price, market, energy, option, curve, would, state, var
# 10          vince, enron, subject, would, com, kaminski, please, research, know, like
# 11          vince, enron, subject, would, com, kaminski, please, research, know, like
# 12                 ect, enron, hou, subject, vince, cc, pm, kaminski, shirley, please
# 13                 ect, enron, hou, subject, vince, cc, pm, kaminski, shirley, please
# 14              model, power, price, market, energy, option, curve, would, state, var
# 15          vince, enron, subject, would, com, kaminski, please, research, know, like
# 16  enron, group, risk, business, management, service, market, new, development, year
# 17  enron, group, risk, business, management, service, market, new, development, year
# 18  enron, group, risk, business, management, service, market, new, development, year
# 19          vince, enron, subject, would, com, kaminski, please, research, know, like
# 20          vince, enron, subject, would, com, kaminski, please, research, know, like
# 21          vince, enron, subject, would, com, kaminski, please, research, know, like
# 22          vince, enron, subject, would, com, kaminski, please, research, know, like
# 23              model, power, price, market, energy, option, curve, would, state, var
# 24          vince, enron, subject, would, com, kaminski, please, research, know, like
#
#                                                                                                    Text
# 0   [subject, institute, international, finance, annual, subscription, shirley, yes, vince, shirley,...
# 1   [subject, synfuel, option, valuation, lenny, believe, must, done, home, work, tax, credit, issue...
# 2   [subject, network, planning, stinson, discussion, jim, said, company, name, mill, three, provide...
# 3   [subject, spreadsheet, george, posey, george, first, cut, problem, gave, done, associate, clayto...
# 4   [subject, fyi, new, esai, report, forecasting, power, price, eastern, market, attached, new, rep...
# 5   [subject, enron, india, newsdesk, may, newsclips, stinson, vince, news, article, read, first, on...
# 6   [subject, resume, molly, would, like, bring, student, summer, intern, last, one, running, space,...
# 7   [subject, nelson, nele, interview, vice, interviewed, nelson, last, week, feedback, communicativ...
# 8   [subject, rice, seminar, hello, fyi, jones, graduate, school, research, seminar, series, finance...
# 9   [subject, efa, meeting, hey, vince, thanks, reply, see, becomes, session, keep, informed, paper,...
# 10  [subject, congratulation, vince, congratulation, mind, always, md, officializing, thank, help, s...
# 11  [subject, kwi, user, group, david, regret, inform, unable, attend, conference, due, previous, co...
# 12  [subject, maureen, raymoin, review, norma, maureen, raymond, refuse, sign, review, please, join,...
# 13  [subject, tage, paul, let, know, made, reservation, thursday, night, june, latour, argent, resta...
# 14  [subject, extreme, value, theory, applied, weathet, dear, vince, grant, currently, reviewing, er...
# 15  [subject, tiger, evals, attachment, tiger, host, understand, host, problem, accessing, database,...
# 16  [subject, year, end, performance, feedback, note, receive, message, time, selected, reviewer, se...
# 17  [subject, maddox, vince, michael, maddox, contact, information, tel, email, mmaddox, cera, com, ...
# 18  [subject, london, update, vince, fuel, discussion, john, sheriff, today, mike, forwarded, mike, ...
# 19  [subject, sfa, license, iris, forwarded, information, donna, lowry, compliance, dept, however, a...
# 20  [subject, question, request, judy, schlesinger, thanks, susan, however, vince, received, financi...
# 21  [subject, alp, presentation, vince, thank, invitation, attend, presentation, another, commitment...
# 22  [subject, presentation, dave, delainey, good, morning, vince, direct, report, give, presentation...
# 23  [subject, fw, pserc, nugget, related, market, stem, hello, shmuel, thanks, message, end, beginni...
# 24  [subject, hello, vince, kaminski, enron, ashley, agree, two, trip, best, solution, unless, cours...

# %%
ham_test_df_dominant_topic = ham_test_df_topic_sents_keywords.reset_index()
ham_test_df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
ham_test_df_dominant_topic.head(25)
# Out:
#     Document_No Dominant_Topic Topic_Perc_Contrib  \
# 0             0              4             0.9889
# 1             1              4              0.808
# 2             2              2              0.917
# 3             3              2             0.7618
# 4             4              2             0.6361
# 5             5              4             0.9917
# 6             6              2             0.8261
# 7             7              4             0.4504
# 8             8              0             0.6756
# 9             9              4             0.8599
# 10           10              0             0.4315
# 11           11              0             0.7219
# 12           12              0             0.5387
# 13           13              1             0.7242
# 14           14              4              0.427
# 15           15              1             0.8609
# 16           16              4             0.5512
# 17           17              2              0.789
# 18           18              1             0.7478
# 19           19              4              0.666
# 20           20              2             0.6647
# 21           21              2             0.9959
# 22           22              1             0.8004
# 23           23              2             0.9862
# 24           24              1             0.6802
#
#                                                                           Keywords  \
# 0                call, enron, may, subject, please, price, model, cera, power, com
# 1                call, enron, may, subject, please, price, model, cera, power, com
# 2     enron, please, subject, metric, new, stinson, need, research, group, network
# 3     enron, please, subject, metric, new, stinson, need, research, group, network
# 4     enron, please, subject, metric, new, stinson, need, research, group, network
# 5                call, enron, may, subject, please, price, model, cera, power, com
# 6     enron, please, subject, metric, new, stinson, need, research, group, network
# 7                call, enron, may, subject, please, price, model, cera, power, com
# 8   enrononline, vince, risk, access, subject, enron, request, hedging, ect, guide
# 9                call, enron, may, subject, please, price, model, cera, power, com
# 10  enrononline, vince, risk, access, subject, enron, request, hedging, ect, guide
# 11  enrononline, vince, risk, access, subject, enron, request, hedging, ect, guide
# 12  enrononline, vince, risk, access, subject, enron, request, hedging, ect, guide
# 13     enron, vince, ect, subject, pm, kaminski, crenshaw, shirley, interview, hou
# 14               call, enron, may, subject, please, price, model, cera, power, com
# 15     enron, vince, ect, subject, pm, kaminski, crenshaw, shirley, interview, hou
# 16               call, enron, may, subject, please, price, model, cera, power, com
# 17    enron, please, subject, metric, new, stinson, need, research, group, network
# 18     enron, vince, ect, subject, pm, kaminski, crenshaw, shirley, interview, hou
# 19               call, enron, may, subject, please, price, model, cera, power, com
# 20    enron, please, subject, metric, new, stinson, need, research, group, network
# 21    enron, please, subject, metric, new, stinson, need, research, group, network
# 22     enron, vince, ect, subject, pm, kaminski, crenshaw, shirley, interview, hou
# 23    enron, please, subject, metric, new, stinson, need, research, group, network
# 24     enron, vince, ect, subject, pm, kaminski, crenshaw, shirley, interview, hou
#
#                                                                                                    Text
# 0   [subject, storage, model, security, stinson, added, time, bomb, security, file, check, model, re...
# 1   [subject, video, conference, ross, mcintyre, vince, received, invitation, lotus, note, outline, ...
# 2   [subject, erisk, iconference, please, save, mail, contains, important, information, event, thank...
# 3   [subject, trading, algorithm, andy, sound, good, one, comment, vasant, swamped, work, coordinati...
# 4   [subject, yes, sir, jeff, thanks, shall, try, arrange, video, conference, houston, howard, back,...
# 5   [subject, ferc, soft, price, cap, mean, cera, conference, call, notification, please, accept, ap...
# 6   [subject, java, class, starting, feb, th, note, upcoming, java, class, extremely, high, interest...
# 7   [subject, eol, wti, historical, trade, simulation, stinson, thanks, lot, much, work, done, simul...
# 8   [subject, fwd, new, commodity, marketplace, opportunity, mark, lay, thank, listening, concept, s...
# 9   [subject, calpx, price, jason, think, may, asking, caliso, power, price, calpx, scheduling, coor...
# 10  [subject, technical, corner, return, sam, forwarded, william, smith, corp, enron, giuseppe, pale...
# 11  [subject, natural, gas, storage, item, vince, something, interesting, natural, gas, storage, cla...
# 12  [subject, global, risk, management, operation, rick, read, memo, regarding, global, risk, manage...
# 13  [subject, enron, recruiting, mscf, speaker, series, vince, pierre, informed, co, ordinate, aliso...
# 14  [subject, petition, summer, internship, celeste, recommending, jason, sokolov, summer, internshi...
# 15  [subject, fw, opportunity, dear, sir, attached, resume, review, meeting, tomorrow, would, best, ...
# 16  [subject, cal, berkeley, career, fair, recruiting, season, quickly, approaching, wanted, go, ahe...
# 17  [subject, resending, paper, forwarded, jason, sokolov, hou, ect, lynn, nazareth, pm, jason, soko...
# 18  [subject, thank, opportunity, hello, vince, heard, sick, hope, thank, opportunity, visit, enron,...
# 19  [subject, eol, phase, deal, written, option, pricing, formula, european, euro, american, amer, a...
# 20  [subject, fw, possible, visit, enron, professor, nalin, kulatilaka, boston, university, iris, wr...
# 21  [subject, new, website, exciting, conference, application, physic, financial, analysis, liege, b...
# 22  [subject, vince, kaminski, bio, hello, amy, attached, please, find, vince, kaminski, bio, workin...
# 23  [subject, wichai, narongwanich, dear, toni, please, arrange, payment, wichai, sigining, bonus, a...
# 24  [subject, subject, hi, vince, resume, look, quite, good, may, wish, talk, phone, however, david,...

# %%
spam_train_df_dominant_topic = spam_train_df_topic_sents_keywords.reset_index()
spam_train_df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
spam_train_df_dominant_topic.head(25)
# Out:
#     Document_No Dominant_Topic Topic_Perc_Contrib  \
# 0             0              3             0.7475
# 1             1              3             0.8117
# 2             2              2             0.7183
# 3             3              1             0.7704
# 4             4              0             0.8513
# 5             5              0             0.9946
# 6             6              2             0.8692
# 7             7              0             0.9947
# 8             8              3             0.6576
# 9             9              3             0.4962
# 10           10              2             0.9932
# 11           11              2             0.8749
# 12           12              1             0.7461
# 13           13              3             0.9888
# 14           14              0              0.996
# 15           15              1             0.9883
# 16           16              3             0.8977
# 17           17              0             0.8728
# 18           18              1             0.6362
# 19           19              3             0.9743
# 20           20              2             0.6344
# 21           21              2             0.9953
# 22           22              0             0.9912
# 23           23              3             0.4507
# 24           24              0             0.4043
#
#                                                                                    Keywords  \
# 0                        subject, email, free, click, new, money, card, business, http, com
# 1                        subject, email, free, click, new, money, card, business, http, com
# 2              adobe, software, subject, save, download, pro, need, customer, price, review
# 3                      com, subject, message, mail, email, http, received, jul, net, viagra
# 4   website, subject, company, please, business, information, www, receive, make, marketing
# 5   website, subject, company, please, business, information, www, receive, make, marketing
# 6              adobe, software, subject, save, download, pro, need, customer, price, review
# 7   website, subject, company, please, business, information, www, receive, make, marketing
# 8                        subject, email, free, click, new, money, card, business, http, com
# 9                        subject, email, free, click, new, money, card, business, http, com
# 10             adobe, software, subject, save, download, pro, need, customer, price, review
# 11             adobe, software, subject, save, download, pro, need, customer, price, review
# 12                     com, subject, message, mail, email, http, received, jul, net, viagra
# 13                       subject, email, free, click, new, money, card, business, http, com
# 14  website, subject, company, please, business, information, www, receive, make, marketing
# 15                     com, subject, message, mail, email, http, received, jul, net, viagra
# 16                       subject, email, free, click, new, money, card, business, http, com
# 17  website, subject, company, please, business, information, www, receive, make, marketing
# 18                     com, subject, message, mail, email, http, received, jul, net, viagra
# 19                       subject, email, free, click, new, money, card, business, http, com
# 20             adobe, software, subject, save, download, pro, need, customer, price, review
# 21             adobe, software, subject, save, download, pro, need, customer, price, review
# 22  website, subject, company, please, business, information, www, receive, make, marketing
# 23                       subject, email, free, click, new, money, card, business, http, com
# 24  website, subject, company, please, business, information, www, receive, make, marketing
#
#                                                                                                    Text
# 0   [subject, mortgage, even, worst, credit, zwzm, detail, want, refinance, fill, quick, form, immed...
# 1   [subject, partnership, mr, edward, moko, independence, close, johannesburg, south, africa, dear,...
# 2   [subject, de, la, part, de, enfants, ama, rue, de, martyr, avenue, delafosse, abidjan, republiqu...
# 3   [subject, considered, unsolicited, bulk, email, message, distmatu, agrocom, com, ar, considered,...
# 4   [subject, get, thru, july, newsletter, get, thru, newslettervenita, king, get, thru, coach, volu...
# 5   [subject, online, sale, low, enough, visitor, submitting, website, search, engine, may, increase...
# 6   [subject, rreally, work, good, hello, welcome, pharmonli, thyroid, ne, newtonian, hop, one, lead...
# 7   [subject, know, get, search, engine, result, submitting, website, search, engine, may, increase,...
# 8   [subject, legal, advice, message, transferred, trial, version, communigate, tm, pro, need, good,...
# 9   [subject, congratulation, new, signups, guarantee, free, signups, ever, pay, penny, show, money,...
# 10  [subject, localized, software, language, available, hello, would, like, offer, localized, softwa...
# 11  [subject, man, stteel, hello, welcome, medzonlin, direction, online, pharmaceutical, sho, feverf...
# 12  [subject, color, printing, special, request, additional, information, click, click, printable, v...
# 13  [subject, largest, membership, site, free, get, porn, free, free, password, asian, huge, tit, xx...
# 14  [subject, http, www, jumpsociety, com, hello, visited, www, jumpsociety, com, noticed, website, ...
# 15  [subject, med, girl, happy, girl, unsatisfied, potency, wait, find, another, men, click, choose,...
# 16  [subject, congratulation, free, lotto, company, uk, head, office, suite, lion, tower, central, l...
# 17  [subject, cool, page, please, active, link, www, informatii, ro, email, sent, unregistered, vers...
# 18  [subject, make, dialup, go, faster, visioson, hpp, za, net, find, revolutionary, hardware, speed...
# 19  [subject, heartwarmer, imagine, welcome, heartwarmers, http, www, heartwarmers, com, best, thing...
# 20  [subject, nawty, local, area, pdi, local, single, inside, payne, cobble, desperado, makeup, dive...
# 21  [subject, graphic, software, available, cheap, oem, version, good, morning, offer, latest, oem, ...
# 22  [subject, save, money, buy, getting, thing, tried, cialls, yet, even, imagine, like, real, man, ...
# 23  [subject, urgent, question, website, hello, name, steve, scott, president, ceo, seizecars, com, ...
# 24  [subject, affect, reporting, agency, account, cancel, consolidate, larger, obligation, declare, ...

# %%
spam_test_df_dominant_topic = spam_test_df_topic_sents_keywords.reset_index()
spam_test_df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
spam_test_df_dominant_topic.head(25)
# Out:
#     Document_No Dominant_Topic Topic_Perc_Contrib  \
# 0             0              1             0.9964
# 1             1              2             0.9829
# 2             2              1             0.8433
# 3             3              1             0.9964
# 4             4              0             0.9953
# 5             5              1             0.8145
# 6             6              0             0.8544
# 7             7              3             0.8062
# 8             8              2             0.6576
# 9             9              0             0.9577
# 10           10              1             0.5903
# 11           11              1             0.9978
# 12           12              2             0.5104
# 13           13              3             0.9905
# 14           14              2             0.8844
# 15           15              4             0.6589
# 16           16              3             0.9967
# 17           17              2             0.6621
# 18           18              0             0.9191
# 19           19              0             0.7085
# 20           20              0             0.6218
# 21           21              3             0.9969
# 22           22              1             0.9964
# 23           23              0             0.9972
# 24           24              3              0.997
#
#                                                                                   Keywords  \
# 0         review, price, adobe, coupon, customer, title, available, sale, system, download
# 1   company, statement, information, stock, com, within, make, email, security, newsletter
# 2         review, price, adobe, coupon, customer, title, available, sale, system, download
# 3         review, price, adobe, coupon, customer, title, available, sale, system, download
# 4        bank, subject, transaction, document, mr, account, company, address, fund, please
# 5         review, price, adobe, coupon, customer, title, available, sale, system, download
# 6        bank, subject, transaction, document, mr, account, company, address, fund, please
# 7                     website, subject, online, save, best, search, way, submit, com, time
# 8   company, statement, information, stock, com, within, make, email, security, newsletter
# 9        bank, subject, transaction, document, mr, account, company, address, fund, please
# 10        review, price, adobe, coupon, customer, title, available, sale, system, download
# 11        review, price, adobe, coupon, customer, title, available, sale, system, download
# 12  company, statement, information, stock, com, within, make, email, security, newsletter
# 13                    website, subject, online, save, best, search, way, submit, com, time
# 14  company, statement, information, stock, com, within, make, email, security, newsletter
# 15           mail, marketing, please, click, one, list, removed, subject, next, technology
# 16                    website, subject, online, save, best, search, way, submit, com, time
# 17  company, statement, information, stock, com, within, make, email, security, newsletter
# 18       bank, subject, transaction, document, mr, account, company, address, fund, please
# 19       bank, subject, transaction, document, mr, account, company, address, fund, please
# 20       bank, subject, transaction, document, mr, account, company, address, fund, please
# 21                    website, subject, online, save, best, search, way, submit, com, time
# 22        review, price, adobe, coupon, customer, title, available, sale, system, download
# 23       bank, subject, transaction, document, mr, account, company, address, fund, please
# 24                    website, subject, online, save, best, search, way, submit, com, time
#
#                                                                                                    Text
# 0   [subject, perfect, logo, charset, koi, thinking, breathing, new, life, business, start, revampin...
# 1   [subject, wall, street, micro, news, report, homeland, security, investment, terror, attack, uni...
# 2   [subject, logo, stationer, website, design, much, lt, really, hard, recollect, company, market, ...
# 3   [subject, perfect, logo, charset, koi, thinking, breathing, new, life, business, start, revampin...
# 4   [subject, save, money, buy, getting, thing, tried, cialls, yet, even, imagine, like, real, man, ...
# 5   [subject, need, outstanding, logo, working, company, image, start, visual, identity, key, first,...
# 6   [subject, ready, get, hello, viagra, med, struggle, men, erectile, dysfunction, like, one, joke,...
# 7   [subject, site, sale, take, credit, card, make, money, easy, set, credit, check, approval, make,...
# 8   [subject, uregent, important, information, website, hello, name, steve, scott, president, ceo, w...
# 9   [subject, secure, account, dear, lasalle, bank, customer, recently, noticed, one, attempt, login...
# 10  [subject, loose, fat, day, overweight, loose, pound, every, day, want, loose, weight, fast, natu...
# 11  [subject, graphic, software, available, cheap, oem, version, good, morning, offer, latest, oem, ...
# 12  [subject, upside, treasury, linked, annuity, upside, annual, increase, year, note, bonus, credit...
# 13  [subject, save, money, getting, oem, software, need, software, pc, visit, site, might, need, bes...
# 14  [subject, aggressive, investor, watching, sport, alumnus, inc, investor, alert, group, investor,...
# 15  [subject, important, start, adult, entertainment, business, entertainment, draw, lot, traffic, s...
# 16  [subject, youu, hello, welcome, pharmon, flatting, line, sh, reflective, op, one, leading, oniin...
# 17  [subject, may, want, look, funding, grant, government, grant, book, edition, receive, money, nee...
# 18                                                                                       [subject, jif]
# 19  [subject, penis, enlargement, announcement, penis, patch, amazing, http, www, okmpoi, com, peopl...
# 20  [subject, custom, design, work, corporate, image, say, lot, thing, company, contemporary, rhythm...
# 21  [subject, cash, dear, homeowner, pre, approved, loan, low, fixed, rate, offer, extended, uncondi...
# 22  [subject, perfect, logo, charset, koi, thinking, breathing, new, life, business, start, revampin...
# 23  [subject, hey, aro, aro, projecthoneypot, projecthoneypot, org, come, join, network, hi, friend,...
# 24  [subject, new, medz, cornel, save, medlcations, pharmsho, enginehouse, successfull, proven, way,...

# %%
pd.options.display.max_colwidth = 100
train_sent_topics_sorteddf_mallet = pd.DataFrame()
train_sent_topics_outdf_grpd = train_df_topic_sents_keywords.groupby('Dominant_Topic')
for i, grp in train_sent_topics_outdf_grpd:
    train_sent_topics_sorteddf_mallet = pd.concat([train_sent_topics_sorteddf_mallet,
                                             grp.sort_values(['Perc_Contribution'], ascending=False).head(1)],
                                            axis=0)
train_sent_topics_sorteddf_mallet.reset_index(drop=True, inplace=True)
train_sent_topics_sorteddf_mallet.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Representative Text"]
train_sent_topics_sorteddf_mallet.head(10)
# Out:
#   Topic_Num Topic_Perc_Contrib  \
# 0         0              0.999
# 1         1             0.9966
# 2         2             0.9973
# 3         3             0.9976
# 4         4             0.9992
#
#                                                                             Keywords  \
# 0                   enron, ect, vince, subject, hou, kaminski, please, would, cc, pm
# 1                  subject, email, free, please, com, http, click, get, new, account
# 2                        com, edu, http, rice, message, subject, mail, id, www, html
# 3         price, model, software, adobe, curve, subject, energy, option, var, system
# 4  company, market, power, investment, business, gas, year, information, may, report
#
#                                                                                    Representative Text
# 0  [subject, hello, vince, kaminski, enron, shmuel, thanks, invitation, speak, october, rd, would, ...
# 1  [subject, desk, top, investigator, astounding, new, software, let, find, almost, anything, anyon...
# 2  [subject, kit, torre, empilhadeira, savi, santos, junho, de, sua, empresa, possui, empilhadeira,...
# 3  [subject, discount, adobe, title, opt, email, special, offer, unsubscribe, search, software, top...
# 4  [subject, start, trading, day, bang, homeland, security, investment, terror, attack, united, sta...

# %%
pd.options.display.max_colwidth = 100
test_sent_topics_sorteddf_mallet = pd.DataFrame()
test_sent_topics_outdf_grpd = test_df_topic_sents_keywords.groupby('Dominant_Topic')
for i, grp in test_sent_topics_outdf_grpd:
    test_sent_topics_sorteddf_mallet = pd.concat([test_sent_topics_sorteddf_mallet,
                                             grp.sort_values(['Perc_Contribution'], ascending=False).head(1)],
                                            axis=0)
test_sent_topics_sorteddf_mallet.reset_index(drop=True, inplace=True)
test_sent_topics_sorteddf_mallet.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Representative Text"]
test_sent_topics_sorteddf_mallet.head(10)
# Out:
#   Topic_Num Topic_Perc_Contrib  \
# 0         0             0.9995
# 1         1             0.9994
# 2         2             0.9987
# 3         3             0.9985
# 4         4             0.9993
#
#                                                                            Keywords  \
# 0                    vince, enron, ect, subject, kaminski, pm, cc, hou, com, please
# 1  power, information, spike, company, business, bank, price, please, account, risk
# 2        list, review, mail, subject, adobe, email, available, price, click, please
# 3        model, make, valuation, company, money, price, year, even, business, stock
# 4         subject, website, online, way, save, de, submit, customer, search, viagra
#
#                                                                                    Representative Text
# 0  [subject, telephone, interview, enron, corp, research, group, since, several, th, moved, telepho...
# 1  [subject, featured, sto, ck, positioned, grow, pop, medium, corp, popt, company, positioned, its...
# 2  [subject, software, title, available, download, opt, email, special, offer, unsubscribe, search,...
# 3  [subject, basic, idea, price, offer, matching, clause, vince, basic, idea, alluding, suppose, ca...
# 4  [subject, iso, clausura, curso, ni, dlos, adolescentes, de, julio, lic, monica, ramos, rodriguez...

# %%
pd.options.display.max_colwidth = 100
ham_train_sent_topics_sorteddf_mallet = pd.DataFrame()
ham_train_sent_topics_outdf_grpd = ham_train_df_topic_sents_keywords.groupby('Dominant_Topic')
for i, grp in ham_train_sent_topics_outdf_grpd:
    ham_train_sent_topics_sorteddf_mallet = pd.concat([ham_train_sent_topics_sorteddf_mallet,
                                             grp.sort_values(['Perc_Contribution'], ascending=False).head(1)],
                                            axis=0)
ham_train_sent_topics_sorteddf_mallet.reset_index(drop=True, inplace=True)
ham_train_sent_topics_sorteddf_mallet.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Representative Text"]
ham_train_sent_topics_sorteddf_mallet.head(10)
# Out:
#   Topic_Num Topic_Perc_Contrib  \
# 0         0             0.9953
# 1         1             0.9981
# 2         2             0.9927
# 3         3             0.9958
# 4         4             0.9968
#
#                                                                             Keywords  \
# 0  enron, group, risk, business, management, service, market, new, development, year
# 1                 ect, enron, hou, subject, vince, cc, pm, kaminski, shirley, please
# 2                 com, edu, rice, http, please, request, www, subject, access, anjam
# 3          vince, enron, subject, would, com, kaminski, please, research, know, like
# 4              model, power, price, market, energy, option, curve, would, state, var
#
#                                                                                    Representative Text
# 0  [subject, restricted, list, neither, ena, rac, egf, employee, family, member, others, living, ho...
# 1  [subject, thanksgiving, staff, meeting, hi, clayton, went, vince, asked, attending, staff, meeti...
# 2  [subject, czesc, ludmilo, wicku, wicusiu, co, slychac, polsce, zimno, ponuro, gdansku, aktualnie...
# 3  [subject, visiting, enron, may, th, susan, thanks, make, sense, call, christie, explain, objecti...
# 4  [subject, california, update, following, report, contains, confidential, sensitive, information,...

# %%
pd.options.display.max_colwidth = 100
spam_train_sent_topics_sorteddf_mallet = pd.DataFrame()
spam_train_sent_topics_outdf_grpd = train_df_topic_sents_keywords.groupby('Dominant_Topic')
for i, grp in spam_train_sent_topics_outdf_grpd:
    spam_train_sent_topics_sorteddf_mallet = pd.concat([spam_train_sent_topics_sorteddf_mallet,
                                             grp.sort_values(['Perc_Contribution'], ascending=False).head(1)],
                                            axis=0)
spam_train_sent_topics_sorteddf_mallet.reset_index(drop=True, inplace=True)
spam_train_sent_topics_sorteddf_mallet.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Representative Text"]
spam_train_sent_topics_sorteddf_mallet.head(10)
# Out:
#   Topic_Num Topic_Perc_Contrib  \
# 0         0              0.999
# 1         1             0.9966
# 2         2             0.9973
# 3         3             0.9976
# 4         4             0.9992
#
#                                                                             Keywords  \
# 0                   enron, ect, vince, subject, hou, kaminski, please, would, cc, pm
# 1                  subject, email, free, please, com, http, click, get, new, account
# 2                        com, edu, http, rice, message, subject, mail, id, www, html
# 3         price, model, software, adobe, curve, subject, energy, option, var, system
# 4  company, market, power, investment, business, gas, year, information, may, report
#
#                                                                                    Representative Text
# 0  [subject, hello, vince, kaminski, enron, shmuel, thanks, invitation, speak, october, rd, would, ...
# 1  [subject, desk, top, investigator, astounding, new, software, let, find, almost, anything, anyon...
# 2  [subject, kit, torre, empilhadeira, savi, santos, junho, de, sua, empresa, possui, empilhadeira,...
# 3  [subject, discount, adobe, title, opt, email, special, offer, unsubscribe, search, software, top...
# 4  [subject, start, trading, day, bang, homeland, security, investment, terror, attack, united, sta...

# %%
pd.options.display.max_colwidth = 100
ham_test_sent_topics_sorteddf_mallet = pd.DataFrame()
ham_test_sent_topics_outdf_grpd = ham_test_df_topic_sents_keywords.groupby('Dominant_Topic')
for i, grp in ham_test_sent_topics_outdf_grpd:
    ham_test_sent_topics_sorteddf_mallet = pd.concat([ham_test_sent_topics_sorteddf_mallet,
                                             grp.sort_values(['Perc_Contribution'], ascending=False).head(1)],
                                            axis=0)
ham_test_sent_topics_sorteddf_mallet.reset_index(drop=True, inplace=True)
ham_test_sent_topics_sorteddf_mallet.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Representative Text"]
ham_test_sent_topics_sorteddf_mallet.head(10)
# Out:
#   Topic_Num Topic_Perc_Contrib  \
# 0         0             0.9992
# 1         1             0.9996
# 2         2             0.9996
# 3         3             0.9989
# 4         4             0.9998
#
#                                                                            Keywords  \
# 0    enrononline, vince, risk, access, subject, enron, request, hedging, ect, guide
# 1       enron, vince, ect, subject, pm, kaminski, crenshaw, shirley, interview, hou
# 2      enron, please, subject, metric, new, stinson, need, research, group, network
# 3  power, spike, portal, price, information, valuation, preprint, model, claim, txu
# 4                 call, enron, may, subject, please, price, model, cera, power, com
#
#                                                                                    Representative Text
# 0  [subject, risk, report, guide, electricxity, hedging, request, fo, gu, est, access, enrononline,...
# 1  [subject, telephone, interview, enron, corp, research, group, since, several, th, moved, telepho...
# 2  [subject, caida, metric, wg, meeting, mar, fwd, hi, amy, jim, irvine, eb, head, network, plannin...
# 3  [subject, model, spike, dear, dr, kaminski, recently, allowed, release, public, domain, limited,...
# 4  [subject, news, article, enron, india, enron, aftermath, business, line, abhay, mehta, copyright...

# %%
pd.options.display.max_colwidth = 100
spam_test_sent_topics_sorteddf_mallet = pd.DataFrame()
spam_test_sent_topics_outdf_grpd = spam_test_df_topic_sents_keywords.groupby('Dominant_Topic')
for i, grp in spam_test_sent_topics_outdf_grpd:
    spam_test_sent_topics_sorteddf_mallet = pd.concat([spam_test_sent_topics_sorteddf_mallet,
                                             grp.sort_values(['Perc_Contribution'], ascending=False).head(1)],
                                            axis=0)
spam_test_sent_topics_sorteddf_mallet.reset_index(drop=True, inplace=True)
spam_test_sent_topics_sorteddf_mallet.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Representative Text"]
spam_test_sent_topics_sorteddf_mallet.head(10)
# Out:
#   Topic_Num Topic_Perc_Contrib  \
# 0         0             0.9992
# 1         1              0.999
# 2         2             0.9995
# 3         3             0.9976
# 4         4             0.9991
#
#                                                                                  Keywords  \
# 0       bank, subject, transaction, document, mr, account, company, address, fund, please
# 1        review, price, adobe, coupon, customer, title, available, sale, system, download
# 2  company, statement, information, stock, com, within, make, email, security, newsletter
# 3                    website, subject, online, save, best, search, way, submit, com, time
# 4           mail, marketing, please, click, one, list, removed, subject, next, technology
#
#                                                                                    Representative Text
# 0  [subject, anticipated, assistant, required, mr, ike, ejoh, bank, manager, diamond, bank, nigeria...
# 1  [subject, software, title, available, download, opt, email, special, offer, unsubscribe, search,...
# 2  [subject, iso, clausura, curso, ni, dlos, adolescentes, de, julio, lic, monica, ramos, rodriguez...
# 3  [subject, online, sale, low, enough, visitor, submitting, website, search, engine, may, increase...
# 4  [subject, internet, news, feed, executive, dfvht, finally, newsfeed, delivers, current, relevant...

# %%
train_doc_lens = [len(d) for d in train_df_dominant_topic.Text]

plt.figure(figsize=(10,5), dpi=160)
plt.hist(train_doc_lens, bins = 100, color='navy')

plt.gca().set(xlim=(0, 100), ylabel='Number of Documents', xlabel='Document Word Count')
plt.tick_params(size=16)
plt.xticks(np.linspace(0,100,9))
plt.title('Distribution of Document Word Counts in training dataset', fontdict=dict(size=22))
plt.show()

# %%
test_doc_lens = [len(d) for d in test_df_dominant_topic.Text]
plt.figure(figsize=(10,5), dpi=160)
plt.hist(test_doc_lens, bins = 100, color='navy')

plt.gca().set(xlim=(0, 100), ylabel='Number of Documents', xlabel='Document Word Count')
plt.tick_params(size=16)
plt.xticks(np.linspace(0,100,9))
plt.title('Distribution of Document Word Counts in testing dataset', fontdict=dict(size=22))
plt.show()

# %%
ham_train_doc_lens = [len(d) for d in ham_train_df_dominant_topic.Text]

plt.figure(figsize=(10,5), dpi=160)
plt.hist(ham_train_doc_lens, bins = 100, color='navy')

plt.gca().set(xlim=(0, 100), ylabel='Number of Documents', xlabel='Document Word Count')
plt.tick_params(size=16)
plt.xticks(np.linspace(0,100,9))
plt.title('Distribution of Document Word Counts in ham training dataset', fontdict=dict(size=22))
plt.show()

# %%
spam_train_doc_lens = [len(d) for d in spam_train_df_dominant_topic.Text]

plt.figure(figsize=(10,5), dpi=160)
plt.hist(spam_train_doc_lens, bins = 100, color='navy')

plt.gca().set(xlim=(0, 100), ylabel='Number of Documents', xlabel='Document Word Count')
plt.tick_params(size=16)
plt.xticks(np.linspace(0,100,9))
plt.title('Distribution of Document Word Counts in spam training dataset', fontdict=dict(size=22))
plt.show()

# %%
ham_test_doc_lens = [len(d) for d in ham_test_df_dominant_topic.Text]
plt.figure(figsize=(10,5), dpi=160)
plt.hist(ham_test_doc_lens, bins = 100, color='navy')

plt.gca().set(xlim=(0, 100), ylabel='Number of Documents', xlabel='Document Word Count')
plt.tick_params(size=16)
plt.xticks(np.linspace(0,100,9))
plt.title('Distribution of Document Word Counts in ham testing dataset', fontdict=dict(size=22))
plt.show()

# %%
spam_test_doc_lens = [len(d) for d in spam_test_df_dominant_topic.Text]
plt.figure(figsize=(10,5), dpi=160)
plt.hist(spam_test_doc_lens, bins = 100, color='navy')

plt.gca().set(xlim=(0, 100), ylabel='Number of Documents', xlabel='Document Word Count')
plt.tick_params(size=16)
plt.xticks(np.linspace(0,100,9))
plt.title('Distribution of Document Word Counts in spam testing dataset', fontdict=dict(size=22))
plt.show()

# %%
from matplotlib import pyplot as plt
from wordcloud import WordCloud, STOPWORDS
import matplotlib.colors as mcolors

cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]

cloud = WordCloud(stopwords=sw,
                  background_color='white',
                  width=2500,
                  height=1800,
                  max_words=10,
                  colormap='tab10',
                  color_func=lambda *args, **kwargs: cols[i],
                  prefer_horizontal=1.0)

topics = train_lda_model.show_topics(formatted=False)

fig, axes = plt.subplots(1, 5, figsize=(10,3), sharex=True, sharey=True)
for i, ax in enumerate(axes.flatten()):
    fig.add_subplot(ax)
    fig.suptitle("Top words per each topic observed from training dataset.", fontsize=18)
    topic_words = dict(topics[i][1])
    cloud.generate_from_frequencies(topic_words, max_font_size=300)
    plt.gca().imshow(cloud)
    plt.gca().set_title('Topic ' + str(i+1), fontdict=dict(size=16))
    plt.gca().axis('off')

plt.subplots_adjust(wspace=0, hspace=0)
plt.axis('off')
plt.margins(x=0, y=0)
plt.tight_layout()
plt.show()

# %%
from matplotlib import pyplot as plt
from wordcloud import WordCloud, STOPWORDS
import matplotlib.colors as mcolors

cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]

cloud = WordCloud(stopwords=sw,
                  background_color='white',
                  width=2500,
                  height=1800,
                  max_words=10,
                  colormap='tab10',
                  color_func=lambda *args, **kwargs: cols[i],
                  prefer_horizontal=1.0)

topics = test_lda_model.show_topics(formatted=False)

fig, axes = plt.subplots(1, 5, figsize=(10,3), sharex=True, sharey=True)

for i, ax in enumerate(axes.flatten()):
    fig.add_subplot(ax)
    fig.suptitle("Top words per each topic observed from testing dataset.", fontsize=18)
    topic_words = dict(topics[i][1])
    cloud.generate_from_frequencies(topic_words, max_font_size=300)
    plt.gca().imshow(cloud)
    plt.gca().set_title('Topic ' + str(i+1), fontdict=dict(size=16))
    plt.gca().axis('off')

plt.subplots_adjust(wspace=0, hspace=0)
plt.axis('off')
plt.margins(x=0, y=0)
plt.tight_layout()
plt.show()

# %%
from matplotlib import pyplot as plt
from wordcloud import WordCloud, STOPWORDS
import matplotlib.colors as mcolors

cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]

cloud = WordCloud(stopwords=sw,
                  background_color='white',
                  width=2500,
                  height=1800,
                  max_words=10,
                  colormap='tab10',
                  color_func=lambda *args, **kwargs: cols[i],
                  prefer_horizontal=1.0)

topics = ham_train_lda_model.show_topics(formatted=False)

fig, axes = plt.subplots(1, 5, figsize=(10,3), sharex=True, sharey=True)
for i, ax in enumerate(axes.flatten()):
    fig.add_subplot(ax)
    fig.suptitle("Top words per each topic observed from ham training dataset.", fontsize=18)
    topic_words = dict(topics[i][1])
    cloud.generate_from_frequencies(topic_words, max_font_size=300)
    plt.gca().imshow(cloud)
    plt.gca().set_title('Topic ' + str(i+1), fontdict=dict(size=16))
    plt.gca().axis('off')

plt.subplots_adjust(wspace=0, hspace=0)
plt.axis('off')
plt.margins(x=0, y=0)
plt.tight_layout()
plt.show()

# %%
# Wordcloud of Top N words in each topic for training dataset
from matplotlib import pyplot as plt
from wordcloud import WordCloud, STOPWORDS
import matplotlib.colors as mcolors

cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]

cloud = WordCloud(stopwords=sw,
                  background_color='white',
                  width=2500,
                  height=1800,
                  max_words=10,
                  colormap='tab10',
                  color_func=lambda *args, **kwargs: cols[i],
                  prefer_horizontal=1.0)

topics = spam_train_lda_model.show_topics(formatted=False)

fig, axes = plt.subplots(1, 5, figsize=(10,3), sharex=True, sharey=True)
for i, ax in enumerate(axes.flatten()):
    fig.add_subplot(ax)
    fig.suptitle("Top words per each topic observed from spam training dataset.", fontsize=18)
    topic_words = dict(topics[i][1])
    cloud.generate_from_frequencies(topic_words, max_font_size=300)
    plt.gca().imshow(cloud)
    plt.gca().set_title('Topic ' + str(i+1), fontdict=dict(size=16))
    plt.gca().axis('off')

plt.subplots_adjust(wspace=0, hspace=0)
plt.axis('off')
plt.margins(x=0, y=0)
plt.tight_layout()
plt.show()

# %%
from matplotlib import pyplot as plt
from wordcloud import WordCloud, STOPWORDS
import matplotlib.colors as mcolors

cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]

cloud = WordCloud(stopwords=sw,
                  background_color='white',
                  width=2500,
                  height=1800,
                  max_words=10,
                  colormap='tab10',
                  color_func=lambda *args, **kwargs: cols[i],
                  prefer_horizontal=1.0)

topics = ham_test_lda_model.show_topics(formatted=False)

fig, axes = plt.subplots(1, 5, figsize=(10,3), sharex=True, sharey=True)

for i, ax in enumerate(axes.flatten()):
    fig.add_subplot(ax)
    fig.suptitle("Top words per each topic observed from ham testing dataset.", fontsize=18)
    topic_words = dict(topics[i][1])
    cloud.generate_from_frequencies(topic_words, max_font_size=300)
    plt.gca().imshow(cloud)
    plt.gca().set_title('Topic ' + str(i+1), fontdict=dict(size=16))
    plt.gca().axis('off')

plt.subplots_adjust(wspace=0, hspace=0)
plt.axis('off')
plt.margins(x=0, y=0)
plt.tight_layout()
plt.show()

# %%
from matplotlib import pyplot as plt
from wordcloud import WordCloud, STOPWORDS
import matplotlib.colors as mcolors

cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]

cloud = WordCloud(stopwords=sw,
                  background_color='white',
                  width=2500,
                  height=1800,
                  max_words=10,
                  colormap='tab10',
                  color_func=lambda *args, **kwargs: cols[i],
                  prefer_horizontal=1.0)

topics = spam_test_lda_model.show_topics(formatted=False)

fig, axes = plt.subplots(1, 5, figsize=(10,3), sharex=True, sharey=True)

for i, ax in enumerate(axes.flatten()):
    fig.add_subplot(ax)
    fig.suptitle("Top words per each topic observed from spam testing dataset.", fontsize=18)
    topic_words = dict(topics[i][1])
    cloud.generate_from_frequencies(topic_words, max_font_size=300)
    plt.gca().imshow(cloud)
    plt.gca().set_title('Topic ' + str(i+1), fontdict=dict(size=16))
    plt.gca().axis('off')

plt.subplots_adjust(wspace=0, hspace=0)
plt.axis('off')
plt.margins(x=0, y=0)
plt.tight_layout()
plt.show()
